# %% [markdown]
# Code source: https://github.com/DerekHodgson/Scraping-AllRecipes/blob/master/scrape.py

# %%
# from urllib.request import urlopen
import requests
from io import BytesIO
import pandas as pd
from bs4 import BeautifulSoup
import re
import pickle
import json
import gc

# %%
# import the scraped URLs
urlList = [line.strip() for line in open('urlList.txt')]

# %%
# number of recipe urls
len(urlList)
# Out:
# 69737

# %%
# remove any duplicates
urlList = list(set(urlList))

# %%
# check number of urls after removing duplicates
# (only one url removed due to duplication)
len(urlList)
# Out:
# 69736

# %%
def get_photo_urls(url):
    photo_urls_list = []
    
    try:
#         page = urlopen(url)
        page = requests.get(url)
        soup = BeautifulSoup(page.text, 'lxml')

        htmlPhotoIDs = re.search('(?<=photoCollection:)(.*}})(?=,)', str(soup)).group(0)
        htmlPhotoIDs = json.loads(htmlPhotoIDs)

        photo_url_root = 'https://images.media-allrecipes.com/userphotos/'
        photo_ext = '.jpg'

        for photo_id in htmlPhotoIDs:
            photo_urls_list.append(photo_url_root + str(photo_id) + photo_ext)
    except:
        pass
        
    return photo_urls_list

# %%
def get_json_info(json_text, soup, recipe_url):
    # get 'title'
    try:
        title = json_text['name'].strip()
    except:
        title = ''
    
    # get 'ratings'
    try:
        ratings = json_text['aggregateRating']['ratingCount']
    except:
        ratings = ''
    
    # get 'avg_rating'
    try:
        avg_rating = json_text['aggregateRating']['ratingValue']
    except:
        avg_rating = ''
    
    # get 'madeit'
    madeit = ''  # 'Made It' not available in this html style recipe
    
    # get 'reviews'
    try:
        reviews = soup.find_all('a', {'class': 'ugc-ratings-link ugc-reviews-link'})[0].text # not in json!
    except:
        reviews = ''
    
    # get 'photos'
    try:
        photos = soup.find_all('a', {'class': 'ugc-ratings-link ugc-photos-link'})[0].text # not in json!
    except:
        photos = ''
    
    # get 'photo_urls'
    photo_urls = []
    
    if photos != '': 
        if int(photos.split()[0]) > 0:
            try:
                main_photo_info = soup.find_all('div', {'class': 'image-container'})[0]
                main_photo_url = re.search('(?<=data-src=")(.*.jpg)(?=")',
                                           str(main_photo_info)).group(1)
                photo_urls.append(main_photo_url)

                photo_slide = soup.find_all(lambda tag: tag.name == 'a' and 
                                            tag.get('class') == ['ugc-photos-link'])
                for i in photo_slide:
                    photo_url = re.search('(?<=data-src=")(.*.jpg)(?=")',
                                          str(i)).group(1)
                    photo_urls.append(photo_url)
            except:
                pass
    
    # get 'description'
    try:
        description = json_text['description'].strip()
    except:
        description = ''
    
    # get 'ingredients_list'
    try:
        ingredients_list = json_text['recipeIngredient']
        ingredients_list = [i.strip() for i in ingredients_list]
    except:
        ingredients_list = []
    
    # get 'readyin' and 'servings'
    try: 
        htmlReady_Servings = soup.find_all('div', {'class': 'recipe-meta-item'})
        ready_servings_list = [' '.join(i.text.lower().split()) for i in htmlReady_Servings]
        ready_servings_dict = {j.split(': ')[0]: j.split(': ')[1] for j in ready_servings_list}
    except:
        ready_servings_dict = {}
        
    try:
        readyin = ready_servings_dict['total']  # not in json!
    except:
        readyin = ''
        
    try:
        servings = ready_servings_dict['servings']  # not in json!
    except:
        servings = ''
    
    # get 'directions_list'
    try:
        htmlDirections = json_text['recipeInstructions']
        directions_list = [d['text'].strip() for d in htmlDirections]
    except:
        directions_list = []
    
    # get 'calories'
    try:
        calories = json_text['nutrition']['calories']
    except:
        calories = ''
    
    # get 'fat'
    try:
        fat = json_text['nutrition']['fatContent']
    except:
        fat = ''
    
    # get 'carbohydrates'
    try:
        carbohydrates = json_text['nutrition']['carbohydrateContent']
    except:
        carbohydrates = ''
    
    # get 'protein'
    try:
        protein = json_text['nutrition']['proteinContent']
    except:
        protein = ''

    # compile recipe info into dictionary and return
    recipe_dict = {'title': title,
                   'recipe_url': recipe_url,
                   'ratings': ratings,  
                   'avg_rating': avg_rating,
                   'madeit': madeit,  # this style html doesn't have 'Made It', but has number of 'Ratings'
                   'reviews': reviews,
                   'photos': photos,
                   'photo_urls': photo_urls,
                   'description': description,
                   'ingredients': ingredients_list,
                   'readyin': readyin,
                   'servings': servings,
                   'directions': directions_list,
                   'calories': calories,
                   'fat': fat,
                   'carbohydrates': carbohydrates,
                   'protein': protein}
    
    return recipe_dict

# %%
def scrape_html_info(soup, recipe_url):
    # get 'title'
    try:
        title = re.search('(?<=<title>)(.*)(?=Recipe - Allrecipes.com)', 
                          str(soup.title)).group(1).strip()
    except:
        title = ''
    
    # get 'ratings'
    ratings = ''  # 'Ratings' not available in this html style recipe
    
    # get rating info ('avg_rating', 'reviews')
    htmlRating = soup.find_all('span', {'itemprop': 'aggregateRating'})
    
    # get 'avg_rating'
    try:
        avg_rating = re.search('(?<=content=")(.*)(?=" itemprop="ratingValue")',
                               str(htmlRating)).group(1)
    except:
        avg_rating = ''
    
    # get 'madeit'
    try:
        madeit = re.search('(?<="made-it-count"></span><span>)(.*)(?=made it)',
                           str(soup)).group(1).split()[0]
    except:
        madeit = ''
    
    # get 'reviews'
    try:
        reviews = re.search('(?<=content=")(.*)(?=" itemprop="reviewCount")',
                            str(htmlRating)).group(1)
    except:
        reviews = ''
    
    # get 'photos'
    try:
        photos = soup.find_all('span', {'class': 'picture-count-link'})[0].text.split()[0]
    except:
        photos = ''
    
    # get 'photo_urls'
    photo_urls = []
    
    if photos != '':
        if int(photos) > 0:
            photos_page_url = soup.find('a', {'class': 'icon-photoPage-link'})['href']
            if photos_page_url is not None:
                photo_urls = get_photo_urls(photos_page_url)
    
    # get 'description'
    try:
        description = soup.find_all('div', {'class': 'submitter__description'})[0].text
    except:
        description = ''
    
    # get 'ingredients'
    htmlIngredients = soup.find_all('span', {'class': "recipe-ingred_txt added"})
    ingredients_list = []
    if htmlIngredients is not None:
        for ingredient in htmlIngredients:
            ingredients_list.append(ingredient.text.strip())
        
    # get 'readyin'
    try:
        readyin = soup.find_all('span', {'class': 'ready-in-time'})[0].text
    except:
        readyin = ''
    
    # get 'servings'
    try:
        servings = soup.find_all('meta', {'itemprop': 'recipeYield'})[0]['content']
    except:
        servings = ''
    
    # get 'directions'
    htmlDirections = soup.find_all('span', {'class': "recipe-directions__list--item"})
    directions_list = []
    if htmlDirections is not None:
        for direction in htmlDirections:
            # sometimes there is an empty direction following the last direction
            if direction.text != '':
                directions_list.append(direction.text.strip())
    
    # get 'calories'
    try:
        calories = soup.find_all('span', {'itemprop': 'calories'})[0].text.split()[0]
    except:
        calories = ''
    
    # get 'fat'
    try:
        fat = soup.find_all('span', {'itemprop': 'fatContent'})[0].text
    except:
        fat = ''
    
    # get 'carbohydrates'
    try:
        carbohydrates = soup.find_all('span', {'itemprop': 'carbohydrateContent'})[0].text
    except:
        carbohydrates = ''
    
    # get 'protein'
    try:
        protein = soup.find_all('span', {'itemprop': 'proteinContent'})[0].text
    except:
        protein = ''
    
    # compile recipe info into dictionary and return
    recipe_dict = {'title': title,
                   'recipe_url': recipe_url,
                   'ratings': ratings,  # this style html doesn't have number of ratings, but has number 'Made It'
                   'avg_rating': avg_rating,
                   'madeit': madeit,
                   'reviews': reviews,
                   'photos': photos,
                   'photo_urls': photo_urls,
                   'description': description,
                   'ingredients': ingredients_list,
                   'readyin': readyin,
                   'servings': servings,
                   'directions': directions_list,
                   'calories': calories,
                   'fat': fat,
                   'carbohydrates': carbohydrates,
                   'protein': protein}
    
    return recipe_dict

# %%
from PIL import Image
import numpy as np

# number of recipes to scrape
n_recipes = len(urlList)

# create empty list to hold recipes and images/labels
recipe_list = []
recipe_image_arrays_with_labels = []

with open("recipe_data.csv", "a") as recipe_file, open("recipe_image_data.csv", "a") as image_file:
    df = pd.DataFrame(columns=['title',
                               'recipe_url',
                               'ratings',
                               'avg_rating', 
                               'madeit', 
                               'reviews', 
                               'photos', 
                               'photo_urls', 
                               'description', 
                               'ingredients', 
                               'readyin', 
                               'servings', 
                               'directions', 
                               'calories', 
                               'fat', 
                               'carbohydrates', 
                               'protein'])
    df.to_csv(recipe_file, index=False)
    
    df_img = pd.DataFrame(columns=['image_array', 
                                   'label'])
    df_img.to_csv(image_file, index=False)
    
    # scrape recipe characteristics from urls
    for i in range(n_recipes):
        print(i)
        print(urlList[i])

        # create empty recipe dictionary
        recipe_dict = {}

        # get website html
#         page = urlopen(urlList[i])
        page = requests.get(urlList[i])
        soup = BeautifulSoup(page.text, "lxml")

        # if source has: <script type="application/ld+json">, 
        # then scrape most info from this json script
        has_json = soup.find('script', type='application/ld+json')
        if has_json is not None:
            json_text = json.loads(has_json.text)[1]
            recipe_dict = get_json_info(json_text, soup, urlList[i])
        else:
            recipe_dict = scrape_html_info(soup, urlList[i])

        # save all images as 64x64x3 arrays to `recipe_image_arrays_with_labels` 
        # list with label (i.e. recipe title)
        label = recipe_dict['title'].lower().strip().replace(' ', '_')

        if recipe_dict['photo_urls'] != []:
            for i in recipe_dict['photo_urls']:
                try:
#                     img = Image.open(urlopen(i))
                    img_page = requests.get(i)
                    img_page_bytes = BytesIO(img_page.content)
                    img = Image.open(img_page_bytes)
                    resized_img = img.resize((64, 64))
                    img_array = np.asarray(resized_img)
                    recipe_image_arrays_with_labels.append([img_array, 
                                                            label])
                    df_img = pd.DataFrame([{'img_array': img_array, 
                                        'label': label}])
                    df_img.to_csv(image_file, header=False, index=False)
                except:
                    pass

        # add recipe dictionary to list of recipes
        recipe_list.append(recipe_dict)

        # add recipe to .csv file output (convert lists to strings delimited by '%>%')
        recipe_dict['photo_urls'] = '%>%'.join(recipe_dict['photo_urls'])
        recipe_dict['ingredients'] = '%>%'.join(recipe_dict['ingredients'])
        recipe_dict['directions'] = '%>%'.join(recipe_dict['directions'])

        df = pd.DataFrame.from_dict([recipe_dict])
        df.to_csv(recipe_file, header=False, index=False)
# Out:
# 0
# https://www.allrecipes.com/recipe/221230/margarita-punch/
# 1
# https://www.allrecipes.com/recipe/19047/chocolate-wafer-roll/
# 2
# https://www.allrecipes.com/recipe/254997/acorn-squash-risotto/
# 3
# https://www.allrecipes.com/recipe/277338/christmas-cobbler/
# 4
# https://www.allrecipes.com/recipe/218329/cool-and-refreshing-cantaloupe-drink/
# 5
# https://www.allrecipes.com/recipe/85256/easy-honey-mustard-mozzarella-chicken/
# 6
# https://www.allrecipes.com/recipe/86938/orzo-with-chicken-and-artichokes/
# 7
# https://www.allrecipes.com/recipe/15451/southern-butternut-squash/
# 8
# https://www.allrecipes.com/recipe/218537/restaurant-style-sausage-gravy-and-biscuits/
# 9
# https://www.allrecipes.com/recipe/213024/cbs-black-eyed-peas/
# 10
# https://www.allrecipes.com/recipe/14679/sesame-beef/
# 11
# https://www.allrecipes.com/recipe/81939/cheesy-chicken-broccoli-bake/
# 12
# https://www.allrecipes.com/recipe/278216/easy-cabbage-onion-and-kale-stir-fry/
# 13
# https://www.allrecipes.com/recipe/269004/one-pot-spaghetti-with-meat-sauce/
# 14
# https://www.allrecipes.com/recipe/8891/cindys-tasty-wings/
# 15
# https://www.allrecipes.com/recipe/237056/coffee-crusted-beef-tenderloin-steak/
# 16
# https://www.allrecipes.com/recipe/9007/jls-cognac-chicken/
# 17
# https://www.allrecipes.com/recipe/215280/refreshing-lentil-salad/
# 18
# https://www.allrecipes.com/recipe/262056/cornes-de-gazelle-gazelle-horns/
# 19
# https://www.allrecipes.com/recipe/11761/unique-spinach-noodles/
# 20
# https://www.allrecipes.com/recipe/87144/divine-summertime-chicken-sandwich/
# 21
# https://www.allrecipes.com/recipe/239529/the-legendary-egg-dog/
# 22
# https://www.allrecipes.com/recipe/151997/alicias-aloo-gobi/
# 23
# https://www.allrecipes.com/recipe/265110/carne-asada-al-chipotle/
# 24
# https://www.allrecipes.com/recipe/245944/spicy-sambal-shrimp/
# 25
# https://www.allrecipes.com/recipe/15444/lyns-chicken/
# 26
# https://www.allrecipes.com/recipe/23848/suet-pudding/
# 27
# https://www.allrecipes.com/recipe/235101/baked-fruit-buckley/
# 28
# https://www.allrecipes.com/recipe/235958/winter-refresher-green-smoothie/
# 29
# https://www.allrecipes.com/recipe/246037/brussels-sprout-pakora/
# 30
# https://www.allrecipes.com/recipe/274226/chicken-curry-with-potatoes-and-lemongrass/
# 31
# https://www.allrecipes.com/recipe/214449/bonquet/
# 32
# https://www.allrecipes.com/recipe/143976/maui-chicken/
# 33
# https://www.allrecipes.com/recipe/16639/jeera-fried-rice/
# 34
# https://www.allrecipes.com/recipe/25654/cheeseburger-soup-iii/
# 500
# https://www.allrecipes.com/recipe/220689/tuscan-sausage-and-chard-soup/
# 501
# https://www.allrecipes.com/recipe/20659/twice-baked-potatoes/
# 502
# https://www.allrecipes.com/recipe/272672/chicken-pesto-saladizza/
# 503
# https://www.allrecipes.com/recipe/140459/yuca-frita/
# 504
# https://www.allrecipes.com/recipe/240704/chicken-mushroom-dijon/
# 505
# https://www.allrecipes.com/recipe/110009/frozen-pineapple-ice-cream-sandwich/
# 506
# https://www.allrecipes.com/recipe/218641/chicken-club-panini/
# 507
# https://www.allrecipes.com/recipe/262606/japanese-american-pocky-sticks/
# 508
# https://www.allrecipes.com/recipe/229772/simple-basil-butter/
# 509
# https://www.allrecipes.com/recipe/25491/whiskey-chicken/
# 510
# https://www.allrecipes.com/recipe/13404/worlds-best-potato-soup/
# 511
# https://www.allrecipes.com/recipe/66277/atomic-tuna-salad/
# 512
# https://www.allrecipes.com/recipe/86026/chocolate-tom-thumb-bars/
# 513
# https://www.allrecipes.com/recipe/275300/jasmine-tea-fruit-salad/
# 514
# https://www.allrecipes.com/recipe/241295/easy-creamy-squash-casserole/
# 515
# https://www.allrecipes.com/recipe/263730/avocado-egg-in-a-hole/
# 516
# https://www.allrecipes.com/recipe/245893/curry-salmon-with-mango/
# 517
# https://www.allrecipes.com/recipe/218997/honey-mustard-sauce-for-dipping/
# 518
# https://www.allrecipes.com/recipe/231059/quick-pumpkin-cake/
# 519
# https://www.allrecipes.com/recipe/276672/banana-breakfast-muffins/
# 520
# https://www.allrecipes.com/recipe/100606/beef-bulgogi/
# 521
# https://www.allrecipes.com/recipe/67862/armenian-rice-pilaf/
# 522
# https://www.allrecipes.com/recipe/222091/healthier-easy-sugar-cookies/
# 523
# https://www.allrecipes.com/recipe/236305/mini-chicken-and-mango-tostadas/
# 524
# https://www.allrecipes.com/recipe/241073/kale-garlic-saute/
# 525
# https://www.allrecipes.com/recipe/272545/ranch-baked-chicken-thighs-with-bacon-brussels-sprouts-and-potatoes/
# 526
# https://www.allrecipes.com/recipe/238062/red-wine-reduction-sauce/
# 527
# https://www.allrecipes.com/recipe/219682/hearty-oatmeal-pancakes/
# 528
# https://www.allrecipes.com/recipe/254164/creamed-stinging-nettles/
# 529
# https://www.allrecipes.com/recipe/264192/decadent-cheesecake-cups/
# 530
# https://www.allrecipes.com/recipe/245295/crispy-fried-tofu/
# 531
# https://www.allrecipes.com/recipe/8948/italian-chicken-marinade/
# 532
# https://www.allrecipes.com/recipe/7268/grandma-snyders-oatmeal-cake/
# 533
# https://www.allrecipes.com/recipe/219293/candy-corn-cupcakes/
# 534
# https://www.allrecipes.com/recipe/244642/5-ingredient-easy-chocolate-chip-cookies/
# 535
# https://www.allrecipes.com/recipe/247476/lemon-verbena-simple-syrup/
# 536
# https://www.allrecipes.com/recipe/152245/uncle-shafs-bohemian-dumplings/
# 537
# https://www.allrecipes.com/recipe/12538/cranberry-streusel-pie/
# 538
# https://www.allrecipes.com/recipe/269429/cheesy-squash-casserole/
# 539
# https://www.allrecipes.com/recipe/216730/cinnamon-heart-popcorn/
# 540
# https://www.allrecipes.com/recipe/255985/festive-eggnog-fudge/
# 541
# https://www.allrecipes.com/recipe/17469/death-by-chocolate-iv/
# 542
# https://www.allrecipes.com/recipe/244282/tropical-grapefruit-sorbet/
# 543
# https://www.allrecipes.com/recipe/228227/grilled-salmon/
# 544
# https://www.allrecipes.com/recipe/51542/egg-foo-yung-with-mushroom-sauce/
# 545
# https://www.allrecipes.com/recipe/178510/lebanese-baked-eggplant/
# 546
# https://www.allrecipes.com/recipe/234095/potato-salad-german-kartoffel/
# 547
# https://www.allrecipes.com/recipe/221974/seared-halibut-with-bacon-and-bean-relish/
# 548
# https://www.allrecipes.com/recipe/229164/creamy-chocolate-mousse-pie/
# 549
# https://www.allrecipes.com/recipe/237693/banana-peanut-butter-smoothie/
# 550
# https://www.allrecipes.com/recipe/24636/fruit-salsa/
# 551
# https://www.allrecipes.com/recipe/273553/chocolate-chai-coffee-cake/
# 552
# https://www.allrecipes.com/recipe/71283/bacon-ranch-pea-salad/
# 553
# https://www.allrecipes.com/recipe/68542/thai-basil-rolls-with-hoisin-peanut-sauce/
# 554
# https://www.allrecipes.com/recipe/274336/cinnamon-roll-peach-cobbler/
# 555
# https://www.allrecipes.com/recipe/10625/frosted-corn-flake-cereal-clusters/
# 556
# https://www.allrecipes.com/recipe/274532/high-protein-snack-bars/
# 557
# https://www.allrecipes.com/recipe/109995/lassy-bread/
# 558
# https://www.allrecipes.com/recipe/222037/tatertot-casserole/
# 559
# https://www.allrecipes.com/recipe/15606/black-bean-spread/
# 560
# https://www.allrecipes.com/recipe/16468/tuna-fish-salad/
# 561
# https://www.allrecipes.com/recipe/17910/banana-snack-cake/
# 562
# https://www.allrecipes.com/recipe/234078/applesauce-for-the-freezer/
# 563
# https://www.allrecipes.com/recipe/247144/baby-food-plum/
# 564
# https://www.allrecipes.com/recipe/216111/sweet-and-spicy-curry-with-chickpeas/
# 565
# https://www.allrecipes.com/recipe/10184/kipfels/
# 566
# https://www.allrecipes.com/recipe/218892/chocolate-frosted-marble-cheesecake/
# 567
# https://www.allrecipes.com/recipe/239221/pumpkin-banana-tofu-smoothie/
# 568
# https://www.allrecipes.com/recipe/220251/asparagus-ham-and-lemon/
# 569
# https://www.allrecipes.com/recipe/13792/pumpkin-pie-squares/
# 570
# https://www.allrecipes.com/recipe/246883/awake-peanut-butter-snack-bites/
# 571
# https://www.allrecipes.com/recipe/99058/cauliflower-and-kale-with-mustard-currant-dressing/
# 572
# https://www.allrecipes.com/recipe/20743/claires-yummy-crepes/
# 573
# https://www.allrecipes.com/recipe/76989/mixed-grill-of-sausage-chicken-and-lamb-with-tandoori-flavorings/
# 574
# https://www.allrecipes.com/recipe/7503/sock-it-to-me-cake-i/
# 575
# https://www.allrecipes.com/recipe/9534/old-fashioned-homemade-hard-candy/
# 576
# https://www.allrecipes.com/recipe/261575/broccoli-slaw-with-spicy-dressing/
# 577
# https://www.allrecipes.com/recipe/223014/passover-pumpkin-muffins/
# 578
# https://www.allrecipes.com/recipe/13816/easy-english-trifle/
# 579
# https://www.allrecipes.com/recipe/24241/spicy-hot-crab-spread/
# 580
# https://www.allrecipes.com/recipe/86411/barbecued-korean-ribs/
# 581
# https://www.allrecipes.com/recipe/275646/slow-cooked-garlic-confit/
# 582
# https://www.allrecipes.com/recipe/258202/billys-fro-yo-doggy-treats/
# 583
# https://www.allrecipes.com/recipe/231310/opals-cherry-delight/
# 584
# https://www.allrecipes.com/recipe/55249/chicken-calvados/
# 585
# https://www.allrecipes.com/recipe/217323/miso-glazed-salmon/
# 586
# https://www.allrecipes.com/recipe/236984/zaxbys-chicken-fingers-dipping-sauce/
# 587
# https://www.allrecipes.com/recipe/263601/gluten-free-vegan-brazilian-cheese-breads/
# 588
# https://www.allrecipes.com/recipe/7595/absolutely-delicious-scratch-cake/
# 589
# https://www.allrecipes.com/recipe/231983/amazingly-succulent-roast-turkey-thighs/
# 590
# https://www.allrecipes.com/recipe/16613/grammys-amazing-cheese-ball/
# 591
# https://www.allrecipes.com/recipe/162671/beef-stifado/
# 592
# https://www.allrecipes.com/recipe/222663/deception-pass-curried-lentil-soup/
# 593
# https://www.allrecipes.com/recipe/190943/spicy-tuna-sushi-roll/
# 594
# https://www.allrecipes.com/recipe/240225/sweet-and-savory-pineapple-pork-loin/
# 595
# https://www.allrecipes.com/recipe/9409/chocolate-cookie-mix-in-a-jar/
# 596
# https://www.allrecipes.com/recipe/275564/moms-christmas-plum-pudding/
# 597
# https://www.allrecipes.com/recipe/261305/crispy-fish-and-chips/
# 598
# https://www.allrecipes.com/recipe/55872/amazing-chicken/
# 599
# https://www.allrecipes.com/recipe/20936/booyah-chicken/
# 600
# https://www.allrecipes.com/recipe/238055/street-taco-with-mango-salsa/
# 601
# https://www.allrecipes.com/recipe/23040/hot-buttered-rum-batter/
# 602
# https://www.allrecipes.com/recipe/57124/vegetarian-sweet-and-sour-meatballs/
# 603
# https://www.allrecipes.com/recipe/236987/chocolate-chicken/
# 604
# https://www.allrecipes.com/recipe/271149/bobbys-smoked-chuck-roast/
# 605
# https://www.allrecipes.com/recipe/55008/apple-lemon-with-cinnamon-muffins/
# 606
# https://www.allrecipes.com/recipe/246392/puerto-rican-canned-corned-beef-stew/
# 607
# https://www.allrecipes.com/recipe/265511/avocado-hummus/
# 608
# https://www.allrecipes.com/recipe/16706/banana-pumpkin-bread/
# 609
# https://www.allrecipes.com/recipe/233338/citrus-and-fennel-salad/
# 610
# https://www.allrecipes.com/recipe/46310/kumquat-orange-marmalade/
# 611
# https://www.allrecipes.com/recipe/230903/oreo-cheesecake/
# 612
# https://www.allrecipes.com/recipe/240253/braised-brussels-sprouts-with-bacon/
# 613
# https://www.allrecipes.com/recipe/257681/creamy-avocado-smoothie/
# 614
# https://www.allrecipes.com/recipe/234421/smore-eyeballs/
# 615
# https://www.allrecipes.com/recipe/228807/blueberry-freezer-jam/
# 616
# https://www.allrecipes.com/recipe/214968/thai-style-cucumber-salad/
# 617
# https://www.allrecipes.com/recipe/258247/moo-shu-vegetable-stir-fry/
# 618
# https://www.allrecipes.com/recipe/240897/honey-steelhead-trout/
# 619
# https://www.allrecipes.com/recipe/261449/cinnamon-star-cookies-with-nutella-hazelnut-spread/
# 620
# https://www.allrecipes.com/recipe/222080/healthier-maries-easy-slow-cooker-pot-roast/
# 621
# https://www.allrecipes.com/recipe/264841/basil-cucumber-smash/
# 622
# https://www.allrecipes.com/recipe/264310/vegan-cilantro-lime-sweet-potato-and-black-bean-tacos/
# 623
# https://www.allrecipes.com/recipe/244950/baked-chicken-schnitzel/
# 624
# https://www.allrecipes.com/recipe/267248/air-fryer-avocado-fries/
# 625
# https://www.allrecipes.com/recipe/237257/good-water/
# 626
# https://www.allrecipes.com/recipe/265672/sesame-brittle/
# 627
# https://www.allrecipes.com/recipe/10987/lavender-cookies/
# 628
# https://www.allrecipes.com/recipe/240945/beef-and-bell-pepper-fajitas/
# 629
# https://www.allrecipes.com/recipe/24039/my-moms-sausage-and-rice-casserole/
# 630
# https://www.allrecipes.com/recipe/230486/chicken-pesto-sandwich/
# 631
# https://www.allrecipes.com/recipe/108206/fruity-sweet-and-sour-sauce/
# 632
# https://www.allrecipes.com/recipe/254340/turkey-spaghetti-zoodles/
# 633
# https://www.allrecipes.com/recipe/273477/breakfast-potato-boats/
# 634
# https://www.allrecipes.com/recipe/276353/key-lime-cookies/
# 635
# https://www.allrecipes.com/recipe/18536/the-old-boys-strawberry-pie/
# 636
# https://www.allrecipes.com/recipe/257763/french-onion-dip-mozzarella-sticks/
# 637
# https://www.allrecipes.com/recipe/27224/green-beans-with-herb-dressing/
# 638
# https://www.allrecipes.com/recipe/57761/herb-roasted-pork/
# 639
# https://www.allrecipes.com/recipe/230569/chef-johns-patatas-bravas/
# 640
# https://www.allrecipes.com/recipe/12351/fiesta-pear-dessert/
# 641
# https://www.allrecipes.com/recipe/18504/buttermilk-biscuits-ii/
# 642
# https://www.allrecipes.com/recipe/24843/lemon-blueberry-bread/
# 643
# https://www.allrecipes.com/recipe/215351/chilled-minty-coconut-melon-soup/
# 644
# https://www.allrecipes.com/recipe/277146/cranberry-sauce-with-orange-zest/
# 645
# https://www.allrecipes.com/recipe/142002/cheese-and-bacon-stuffed-pasta-shells/
# 646
# https://www.allrecipes.com/recipe/229270/spicy-rice-noodle-salad/
# 647
# https://www.allrecipes.com/recipe/21466/oven-baked-caramel-french-toast/
# 648
# https://www.allrecipes.com/recipe/25812/easiest-cracker-cookies/
# 649
# https://www.allrecipes.com/recipe/222727/sausage-and-kale-soup/
# 650
# https://www.allrecipes.com/recipe/233009/celery-almandine/
# 651
# https://www.allrecipes.com/recipe/222603/soft-chocolate-cookies/
# 652
# https://www.allrecipes.com/recipe/239376/sweet-potatoes-with-zest/
# 653
# https://www.allrecipes.com/recipe/22848/ashleys-chocolate-chip-cookies/
# 654
# https://www.allrecipes.com/recipe/231807/chicken-wild-rice-stuffed-red-peppers/
# 655
# https://www.allrecipes.com/recipe/19028/creme-brulee-iv/
# 656
# https://www.allrecipes.com/recipe/260316/easy-halloween-mummy-cupcakes/
# 657
# https://www.allrecipes.com/recipe/82135/polish-noodles/
# 658
# https://www.allrecipes.com/recipe/221434/spicy-enchiladas-verdes-de-queso/
# 659
# https://www.allrecipes.com/recipe/7540/buttery-cinnamon-cake/
# 660
# https://www.allrecipes.com/recipe/212450/brazilian-peanut-fudge/
# 661
# https://www.allrecipes.com/recipe/13699/apricot-brandy-and-peach-schnapps-pound-cake/
# 662
# https://www.allrecipes.com/recipe/22550/easy-mashed-sweet-potatoes/
# 663
# https://www.allrecipes.com/recipe/11501/finnish-kropser-baked-pancakes/
# 664
# https://www.allrecipes.com/recipe/256876/steak-au-poivre-flambe/
# 665
# https://www.allrecipes.com/recipe/87649/linguine-with-spinach-and-brie/
# 666
# https://www.allrecipes.com/recipe/9396/choco-shortbreads/
# 667
# https://www.allrecipes.com/recipe/247465/porcini-mushroom-soup/
# 668
# https://www.allrecipes.com/recipe/275693/pumpkin-cream-cheese-bundt-cake/
# 669
# https://www.allrecipes.com/recipe/257044/salted-almond-sunflower-energy-bites/
# 670
# https://www.allrecipes.com/recipe/231574/simple-garlic-dip/
# 671
# https://www.allrecipes.com/recipe/237786/baked-pasta-casserole/
# 672
# https://www.allrecipes.com/recipe/245475/veggie-pizzadillas/
# 673
# https://www.allrecipes.com/recipe/13218/absolutely-ultimate-potato-soup/
# 674
# https://www.allrecipes.com/recipe/270622/peruvian-aji-verde/
# 675
# https://www.allrecipes.com/recipe/33175/baked-cider-doughnuts/
# 676
# https://www.allrecipes.com/recipe/236024/kahlua-fruit-dip/
# 677
# https://www.allrecipes.com/recipe/268286/fig-and-raisin-bread/
# 678
# https://www.allrecipes.com/recipe/203488/alaska-sheet-cake/
# 679
# https://www.allrecipes.com/recipe/233076/gingersnap-fresh-peach-pie/
# 680
# https://www.allrecipes.com/recipe/202252/scrumptious-penuche-frosting/
# 681
# https://www.allrecipes.com/recipe/14473/warm-orange-and-mushroom-salad/
# 682
# https://www.allrecipes.com/recipe/160603/bonds-vesper/
# 683
# https://www.allrecipes.com/recipe/20906/doctor-bird-cake/
# 684
# https://www.allrecipes.com/recipe/106584/campfire-foil-packs/
# 685
# https://www.allrecipes.com/recipe/232428/habanero-cream-sauce/
# 686
# https://www.allrecipes.com/recipe/267637/simple-peach-salsa/
# 687
# https://www.allrecipes.com/recipe/26021/creme-de-menthe-cake-ii/
# 688
# https://www.allrecipes.com/recipe/17536/italian-cassata-cake/
# 689
# https://www.allrecipes.com/recipe/258166/the-best-vanilla-bean-cheesecake/
# 690
# https://www.allrecipes.com/recipe/149302/tomato-and-bread-soup/
# 691
# https://www.allrecipes.com/recipe/239113/billy-boys-butter-tart-slice/
# 692
# https://www.allrecipes.com/recipe/217109/make-ahead-vegetarian-moroccan-stew/
# 693
# https://www.allrecipes.com/recipe/233888/mudslide-mousse-shots/
# 694
# https://www.allrecipes.com/recipe/129065/easy-peasy-rice-bake/
# 695
# https://www.allrecipes.com/recipe/261202/pumpkin-almond-date-balls/
# 696
# https://www.allrecipes.com/recipe/6979/bread-bowls-i/
# 697
# https://www.allrecipes.com/recipe/257492/happy-skinny-green-smoothie/
# 698
# https://www.allrecipes.com/recipe/27491/aunt-annes-coffee-cake/
# 699
# https://www.allrecipes.com/recipe/245438/homemade-flax-seed-milk/
# 700
# https://www.allrecipes.com/recipe/16382/mexicali-pork-chops/
# 701
# https://www.allrecipes.com/recipe/218623/pecan-toffee-squares/
# 702
# https://www.allrecipes.com/recipe/229056/frozen-strawberry-yogurt/
# 703
# https://www.allrecipes.com/recipe/265518/spaghetti-squash-au-gratin-with-bechamel-sauce/
# 704
# https://www.allrecipes.com/recipe/8605/veneto-chicken/
# 705
# https://www.allrecipes.com/recipe/38855/brown-mixers/
# 706
# https://www.allrecipes.com/recipe/154971/caribbean-beef-loin-steaks/
# 707
# https://www.allrecipes.com/recipe/240394/titis-cranberry-walnut-pumpkin-bread-cake/
# 708
# https://www.allrecipes.com/recipe/230309/eggnog-and-sprite-winter-punch/
# 709
# https://www.allrecipes.com/recipe/70343/slow-cooker-chicken-taco-soup/
# 710
# https://www.allrecipes.com/recipe/242412/spicy-chicken-noodle-soup/
# 711
# https://www.allrecipes.com/recipe/236092/kale-and-mushroom-side/
# 712
# https://www.allrecipes.com/recipe/266312/fresh-peach-galette/
# 713
# https://www.allrecipes.com/recipe/7614/lane-cake-filling/
# 714
# https://www.allrecipes.com/recipe/240633/roast-beef-horseradish-sauce/
# 715
# https://www.allrecipes.com/recipe/19863/best-burger-ever/
# 716
# https://www.allrecipes.com/recipe/14361/marilyns-special-salad/
# 717
# https://www.allrecipes.com/recipe/25401/pizza-sauce-i/
# 718
# https://www.allrecipes.com/recipe/19299/fettuccine-with-garlic-herb-butter/
# 719
# https://www.allrecipes.com/recipe/59866/modenese-pork-chops/
# 720
# https://www.allrecipes.com/recipe/26727/cheese-ball-iii/
# 721
# https://www.allrecipes.com/recipe/8830/mushroom-chicken-parmesan/
# 722
# https://www.allrecipes.com/recipe/87547/sues-beans/
# 723
# https://www.allrecipes.com/recipe/13093/solianka-or-russian-beef-soup/
# 724
# https://www.allrecipes.com/recipe/141902/strawberry-cupcakes/
# 725
# https://www.allrecipes.com/recipe/255959/pecan-crusted-chicken-with-grapes/
# 726
# https://www.allrecipes.com/recipe/241707/joys-easy-banana-bread/
# 727
# https://www.allrecipes.com/recipe/19546/pumpkin-torte-ii/
# 728
# https://www.allrecipes.com/recipe/139803/blueberry-liquor/
# 729
# https://www.allrecipes.com/recipe/88328/fresco-salsa/
# 730
# https://www.allrecipes.com/recipe/172747/sweet-and-spicy-sweet-potatoes/
# 731
# https://www.allrecipes.com/recipe/270070/anti-inflammatory-sweet-potato-soup/
# 732
# https://www.allrecipes.com/recipe/236560/very-orange-smoothie-without-oranges/
# 733
# https://www.allrecipes.com/recipe/275577/affogato/
# 734
# https://www.allrecipes.com/recipe/232310/napa-slaw/
# 735
# https://www.allrecipes.com/recipe/246863/easy-scrambled-eggs/
# 736
# https://www.allrecipes.com/recipe/244671/mallow-nutter-milk-shake/
# 737
# https://www.allrecipes.com/recipe/263931/vegan-lentil-salad-with-apples-and-carrot/
# 738
# https://www.allrecipes.com/recipe/245632/florida-sunset-blackened-tilapia/
# 739
# https://www.allrecipes.com/recipe/236965/palacinky/
# 740
# https://www.allrecipes.com/recipe/9422/southern-boiled-custard/
# 741
# https://www.allrecipes.com/recipe/178742/dublin-coddle/
# 742
# https://www.allrecipes.com/recipe/270837/garlic-chicken-with-honey-and-rosemary/
# 743
# https://www.allrecipes.com/recipe/239696/betsys-old-fashioned-manhattan/
# 744
# https://www.allrecipes.com/recipe/256103/asian-shrimp-packets/
# 745
# https://www.allrecipes.com/recipe/232738/spinach-and-beet-salad/
# 746
# https://www.allrecipes.com/recipe/245309/cornbread-stuffed-bacon-wrapped-pork-tenderloin/
# 747
# https://www.allrecipes.com/recipe/19790/almond-puff-cake/
# 748
# https://www.allrecipes.com/recipe/233515/bass-for-dinner/
# 749
# https://www.allrecipes.com/recipe/149310/self-rising-flour/
# 750
# https://www.allrecipes.com/recipe/240894/black-bean-and-quinoa-enchilada-bake/
# 751
# https://www.allrecipes.com/recipe/164254/chinese-mabo-tofu/
# 752
# https://www.allrecipes.com/recipe/215073/hot-pepper-sauce-a-trinidadian-staple/
# 753
# https://www.allrecipes.com/recipe/255490/pumpkin-crunch-pudding-cake/
# 754
# https://www.allrecipes.com/recipe/84270/slow-cooker-corned-beef-and-cabbage/
# 755
# https://www.allrecipes.com/recipe/42164/supreme-apple-butter/
# 756
# https://www.allrecipes.com/recipe/25219/ham-and-cheese-chop-chop/
# 757
# https://www.allrecipes.com/recipe/23562/my-kids-favorite-pork-chops/
# 758
# https://www.allrecipes.com/recipe/235992/healthy-protein-morning-glory-muffins/
# 759
# https://www.allrecipes.com/recipe/228286/savory-baked-bagel-chips/
# 760
# https://www.allrecipes.com/recipe/255016/sweet-potato-creme-brulee/
# 761
# https://www.allrecipes.com/recipe/18289/garlic-grits/
# 762
# https://www.allrecipes.com/recipe/147337/oven-spam-sandwiches/
# 763
# https://www.allrecipes.com/recipe/273847/christmas-potatoes/
# 764
# https://www.allrecipes.com/recipe/161819/bacon-gravy-for-biscuits/
# 765
# https://www.allrecipes.com/recipe/244824/faux-cookie-dough-dip/
# 766
# https://www.allrecipes.com/recipe/141972/teenas-overnight-southern-buttermilk-biscuits/
# 767
# https://www.allrecipes.com/recipe/68839/papaya-bruschetta/
# 768
# https://www.allrecipes.com/recipe/241433/chocolate-hazelnut-rolls/
# 769
# https://www.allrecipes.com/recipe/277876/gabes-buffalo-ranch-snack-mix/
# 770
# https://www.allrecipes.com/recipe/204813/savory-cheddar-zucchini-muffins/
# 771
# https://www.allrecipes.com/recipe/231987/twice-baked-potato-casserole/
# 772
# https://www.allrecipes.com/recipe/260015/bloody-skeleton-smores/
# 773
# https://www.allrecipes.com/recipe/25802/special-cookies/
# 774
# https://www.allrecipes.com/recipe/261996/easy-slow-cooker-chicken-curry-with-potatoes-and-coconut-milk/
# 775
# https://www.allrecipes.com/recipe/234628/fruit-crisp-breakfast-skillet/
# 776
# https://www.allrecipes.com/recipe/222009/3-cheese-enchiladas/
# 777
# https://www.allrecipes.com/recipe/215694/lower-salt-dried-onion-soup-mix/
# 778
# https://www.allrecipes.com/recipe/73752/yellow-squash/
# 779
# https://www.allrecipes.com/recipe/262505/banana-gingerbread-with-vanilla-glaze/
# 780
# https://www.allrecipes.com/recipe/246757/lemony-pork-piccata/
# 781
# https://www.allrecipes.com/recipe/14591/the-best-marinade-around/
# 782
# https://www.allrecipes.com/recipe/216683/wisconsin-blue-ribbon-chili/
# 783
# https://www.allrecipes.com/recipe/105301/catfish-with-tropical-fruit-salsa/
# 784
# https://www.allrecipes.com/recipe/85194/semmelknoedel-bread-dumplings/
# 785
# https://www.allrecipes.com/recipe/7012/cottage-cheese-bread-ii/
# 786
# https://www.allrecipes.com/recipe/10343/lebkuchen-ii/
# 787
# https://www.allrecipes.com/recipe/218354/ravens-beef-stew/
# 788
# https://www.allrecipes.com/recipe/71341/icy-blender-lemonade/
# 789
# https://www.allrecipes.com/recipe/236969/easy-microwave-chicken-divan/
# 790
# https://www.allrecipes.com/recipe/148889/sauteed-swiss-chard-with-parmesan-cheese/
# 791
# https://www.allrecipes.com/recipe/222890/mexican-coffee-cocktail/
# 792
# https://www.allrecipes.com/recipe/275467/spicy-chicken-enchiladas-with-tomatillo-salsa/
# 793
# https://www.allrecipes.com/recipe/166568/dijon-and-avocado-rubbed-beef-tenderloin-roast/
# 794
# https://www.allrecipes.com/recipe/258692/simple-summer-java-float/
# 795
# https://www.allrecipes.com/recipe/61327/fresh-vegetable-stir-fry-with-peppery-orange-beef/
# 796
# https://www.allrecipes.com/recipe/91906/singapore-sling-slush/
# 797
# https://www.allrecipes.com/recipe/259755/delicious-sweet-potato-pie-recipe/
# 798
# https://www.allrecipes.com/recipe/258051/chicken-brown-rice-sloppy-joes/
# 799
# https://www.allrecipes.com/recipe/223420/dads-working-mans-macaroni-salad/
# 800
# https://www.allrecipes.com/recipe/240641/salt-dough/
# 801
# https://www.allrecipes.com/recipe/220158/turkey-cranberry-wreath-bake/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-3b07eec77aaf> in <module>
#      43         # get website html
#      44 #         page = urlopen(urlList[i])
# ---> 45         page = requests.get(urlList[i])
#      46         soup = BeautifulSoup(page.text, "lxml")
#      47
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     488         """
#     489         if self.chunked and self.supports_chunked_reads():
# --> 490             for line in self.read_chunked(amt, decode_content=decode_content):
#     491                 yield line
#     492         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     664
#     665             while True:
# --> 666                 self._update_chunk_length()
#     667                 if self.chunk_left == 0:
#     668                     break
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/response.py in _update_chunk_length(self)
#     596         if self.chunk_left is not None:
#     597             return
# --> 598         line = self._fp.fp.readline()
#     599         line = line.split(b';', 1)[0]
#     600         try:
#
# ~/opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:
